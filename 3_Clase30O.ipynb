# %% [markdown]
# <a href="https://colab.research.google.com/github/cmgpcinthia/Big_Data_Machine_Learning/blob/main/3_Clase30O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exploracion de JSONs

# %%
import json
import requests

# %%
r = requests.get("https://datosabiertos.malaga.eu/recursos/transporte/EMT/EMTlineasUbicaciones/lineasyubicaciones.geojson")

# %%
r.text
# Out:
# '[\n    {\n        "geometry_name": "wkb_geometry", \n        "geometry": {\n            "type": "Point", \n            "coordinates": [\n                "-4.4141808", \n                "36.726593"\n            ]\n        }, \n        "codBus": "564", \n        "codLinea": "1.0", \n        "sentido": "2", \n        "type": "Feature", \n        "properties": {\n            "codLinea": "1.0", \n            "codBus": "564", \n            "sentido": "2", \n            "codParIni": "508", \n            "last_update": "2025-10-30 16:45:06"\n        }, \n        "codParIni": "508"\n    }, \n    {\n        "geometry_name": "wkb_geometry", \n        "geometry": {\n            "type": "Point", \n            "coordinates": [\n                "-4.42371", \n                "36.734455"\n            ]\n        }, \n        "codBus": "640", \n        "codLinea": "1.0", \n        "sentido": "1", \n        "type": "Feature", \n        "properties": {\n            "codLinea": "1.0", \n            "codB
# ...

# %%
json.loads(r.text)
# Out:
# [{'geometry_name': 'wkb_geometry',
#   'geometry': {'type': 'Point', 'coordinates': ['-4.4141808', '36.726593']},
#   'codBus': '564',
#   'codLinea': '1.0',
#   'sentido': '2',
#   'type': 'Feature',
#   'properties': {'codLinea': '1.0',
#    'codBus': '564',
#    'sentido': '2',
#    'codParIni': '508',
#    'last_update': '2025-10-30 16:45:06'},
#   'codParIni': '508'},
#  {'geometry_name': 'wkb_geometry',
#   'geometry': {'type': 'Point', 'coordinates': ['-4.42371', '36.734455']},
#   'codBus': '640',
#   'codLinea': '1.0',
#   'sentido': '1',
#   'type': 'Feature',
#   'properties': {'codLinea': '1.0',
#    'codBus': '640',
#    'sentido': '1',
#    'codParIni': '153',
#    'last_update': '2025-10-30 16:45:06'},
#   'codParIni': '153'},
#  {'geometry_name': 'wkb_geometry',
#   'geometry': {'type': 'Point', 'coordinates': ['-4.4316063', '36.710995']},
#   'codBus': '641',
#   'codLinea': '1.0',
#   'sentido': '1',
#   'type': 'Feature',
#   'properties': {'codLinea': '1.0',
# ...

# %%
emt = json.loads(r.text)

# %%
emt [0]
# Out:
# {'geometry_name': 'wkb_geometry',
#  'geometry': {'type': 'Point', 'coordinates': ['-4.4141808', '36.726593']},
#  'codBus': '564',
#  'codLinea': '1.0',
#  'sentido': '2',
#  'type': 'Feature',
#  'properties': {'codLinea': '1.0',
#   'codBus': '564',
#   'sentido': '2',
#   'codParIni': '508',
#   'last_update': '2025-10-30 16:45:06'},
#  'codParIni': '508'}

# %%
emt [0]["codBus"]
# Out:
# '564'

# %%
emt [0]["geometry"]
# Out:
# {'type': 'Point', 'coordinates': ['-4.4141808', '36.726593']}

# %%
emt [0]["geometry"]["coordinates"]
#Para llegar a las coordenadas subcarpetas dentro de la carperta por el nivel
# Out:
# ['-4.4141808', '36.726593']

# %%
x= emt [0]["geometry"]["coordinates"][0]
y = emt [0]["geometry"]["coordinates"][1]
print (x,y)
# Out:
# -4.4141808 36.726593

# %%
emt[0].keys()
# Out:
# dict_keys(['geometry_name', 'geometry', 'codBus', 'codLinea', 'sentido', 'type', 'properties', 'codParIni'])

# %%
len(emt)
# Out:
# 168

# %%
for autobus in emt:
  linea = emt [i]["codBus"]
  x= autobus["geometry"]["coordinates"][0]
  y =autobus["geometry"]["coordinates"][1]

  print (linea,x,y)
# Out:
# 703 -4.4141808 36.726593
# 703 -4.42371 36.734455
# 703 -4.4316063 36.710995
# 703 -4.427051 36.71592
# 703 -4.445292 36.70226
# 703 -4.4614935 36.69475
# 703 -4.456848 36.6977
# 703 -4.413826 36.72923
# 703 -4.4542756 36.699013
# 703 -4.422705 36.717655
# 703 -4.4268355 36.716984
# 703 -4.4140453 36.72716
# 703 -4.4268494 36.731045
# 703 -4.425623 36.755535
# 703 -4.425119 36.7198
# 703 -4.4383926 36.702682
# 703 -4.4273744 36.716446
# 703 -4.3484564 36.721954
# 703 -4.4271417 36.717793
# 703 -4.430117 36.712204
# 703 -4.3680058 36.722507
# 703 -4.3984146 36.72294
# 703 -4.3695517 36.722534
# 703 -4.4519153 36.690163
# 703 -4.3533807 36.72052
# 703 -4.412235 36.72062
# 703 -4.4503803 36.69126
# 703 -4.461956 36.708534
# 703 -4.463905 36.71742
# 703 -4.4231853 36.717587
# 703 -4.413281 36.720264
# 703 -4.4470925 36.711124
# 703 -4.4665184 36.683502
# 703 -4.483809 36.656677
# 703 -4.430261 36.712112
# 703 -4.4588566 36.683144
# 703 -4.448168 36.73024
# 703 -4.443513 36.729233
# ...

# %%
for i in range (len(emt)):
  linea = emt[i]["codBus"]
  x= emt[i]["geometry"]["coordinates"][0]
  y =emt[i]["geometry"]["coordinates"][1]
  print(linea,x,y)
# Out:
# 564 -4.4141808 36.726593
# 640 -4.42371 36.734455
# 641 -4.4316063 36.710995
# 647 -4.427051 36.71592
# 656 -4.445292 36.70226
# 671 -4.4614935 36.69475
# 675 -4.456848 36.6977
# 679 -4.413826 36.72923
# 684 -4.4542756 36.699013
# 687 -4.422705 36.717655
# 688 -4.4268355 36.716984
# 694 -4.4140453 36.72716
# 572 -4.4268494 36.731045
# 574 -4.425623 36.755535
# 775 -4.425119 36.7198
# 525 -4.4383926 36.702682
# 532 -4.4273744 36.716446
# 536 -4.3484564 36.721954
# 537 -4.4271417 36.717793
# 546 -4.430117 36.712204
# 606 -4.3680058 36.722507
# 610 -4.3984146 36.72294
# 625 -4.3695517 36.722534
# 712 -4.4519153 36.690163
# 732 -4.3533807 36.72052
# 736 -4.412235 36.72062
# 755 -4.4503803 36.69126
# 528 -4.461956 36.708534
# 710 -4.463905 36.71742
# 713 -4.4231853 36.717587
# 715 -4.413281 36.720264
# 716 -4.4470925 36.711124
# 650 -4.4665184 36.683502
# 659 -4.483809 36.656677
# 668 -4.430261 36.712112
# 569 -4.4588566 36.683144
# 578 -4.448168 36.73024
# 592 -4.443513 36.729233
# ...

# %%
#Final del ejercicio#
#Nuevo Ejercicio#

# %%
r = requests.get("https://apidatos.ree.es/es/datos/mercados/precios-mercados-tiempo-real?start_date=2025-10-30T00:00&end_date=2025-10-30T23:59&time_trunc=hour")

# %%
r.text
# Out:
# '{"data":{"type":"Precios mercado peninsular en tiempo real","id":"mer13","attributes":{"title":"Precios mercado peninsular en tiempo real","last-update":"2025-10-29T20:46:27.000+01:00","description":null},"meta":{"cache-control":{"cache":"HIT","expireAt":"2025-10-31T09:55:21"}}},"included":[{"type":"PVPC","id":"1001","groupId":null,"attributes":{"title":"PVPC","description":null,"color":"#ffcf09","icon":null,"type":null,"magnitude":"price","composite":false,"last-update":"2025-10-29T20:46:27.000+01:00","values":[{"value":154.99,"percentage":0.5611919762473749,"datetime":"2025-10-30T00:00:00.000+01:00"},{"value":146.04,"percentage":0.5539581989910101,"datetime":"2025-10-30T01:00:00.000+01:00"},{"value":138.81,"percentage":0.5647044465237379,"datetime":"2025-10-30T02:00:00.000+01:00"},{"value":133.61,"percentage":0.5617642112344433,"datetime":"2025-10-30T03:00:00.000+01:00"},{"value":123.62,"percentage":0.559062952243126,"datetime":"2025-10-30T04:00:00.000+01:00"},{"value":121.38,"per
# ...

# %%
json.loads(r.text)
# Out:
# {'data': {'type': 'Precios mercado peninsular en tiempo real',
#   'id': 'mer13',
#   'attributes': {'title': 'Precios mercado peninsular en tiempo real',
#    'last-update': '2025-10-29T20:46:27.000+01:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'HIT',
#     'expireAt': '2025-10-31T09:55:21'}}},
#  'included': [{'type': 'PVPC',
#    'id': '1001',
#    'groupId': None,
#    'attributes': {'title': 'PVPC',
#     'description': None,
#     'color': '#ffcf09',
#     'icon': None,
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2025-10-29T20:46:27.000+01:00',
#     'values': [{'value': 154.99,
#       'percentage': 0.5611919762473749,
#       'datetime': '2025-10-30T00:00:00.000+01:00'},
#      {'value': 146.04,
#       'percentage': 0.5539581989910101,
#       'datetime': '2025-10-30T01:00:00.000+01:00'},
#      {'value': 138.81,
#       'percentage': 0.5647044465237379,
# ...

# %%
elect = json.loads(r.text)

# %%
elect["included"][0]
# Out:
# {'type': 'PVPC',
#  'id': '1001',
#  'groupId': None,
#  'attributes': {'title': 'PVPC',
#   'description': None,
#   'color': '#ffcf09',
#   'icon': None,
#   'type': None,
#   'magnitude': 'price',
#   'composite': False,
#   'last-update': '2025-10-29T20:46:27.000+01:00',
#   'values': [{'value': 154.99,
#     'percentage': 0.5611919762473749,
#     'datetime': '2025-10-30T00:00:00.000+01:00'},
#    {'value': 146.04,
#     'percentage': 0.5539581989910101,
#     'datetime': '2025-10-30T01:00:00.000+01:00'},
#    {'value': 138.81,
#     'percentage': 0.5647044465237379,
#     'datetime': '2025-10-30T02:00:00.000+01:00'},
#    {'value': 133.61,
#     'percentage': 0.5617642112344433,
#     'datetime': '2025-10-30T03:00:00.000+01:00'},
#    {'value': 123.62,
#     'percentage': 0.559062952243126,
#     'datetime': '2025-10-30T04:00:00.000+01:00'},
#    {'value': 121.38,
#     'percentage': 0.5742536783838765,
#     'datetime': '2025-10-30T05:00:00.000+01:00'},
#    {'value': 139.94,
# ...

# %%
elect["included"][0]["attributes"]["values"]
# Out:
# [{'value': 154.99,
#   'percentage': 0.5611919762473749,
#   'datetime': '2025-10-30T00:00:00.000+01:00'},
#  {'value': 146.04,
#   'percentage': 0.5539581989910101,
#   'datetime': '2025-10-30T01:00:00.000+01:00'},
#  {'value': 138.81,
#   'percentage': 0.5647044465237379,
#   'datetime': '2025-10-30T02:00:00.000+01:00'},
#  {'value': 133.61,
#   'percentage': 0.5617642112344433,
#   'datetime': '2025-10-30T03:00:00.000+01:00'},
#  {'value': 123.62,
#   'percentage': 0.559062952243126,
#   'datetime': '2025-10-30T04:00:00.000+01:00'},
#  {'value': 121.38,
#   'percentage': 0.5742536783838765,
#   'datetime': '2025-10-30T05:00:00.000+01:00'},
#  {'value': 139.94,
#   'percentage': 1,
#   'datetime': '2025-10-30T06:00:00.000+01:00'},
#  {'value': 159.68,
#   'percentage': 1,
#   'datetime': '2025-10-30T07:00:00.000+01:00'},
#  {'value': 183.9,
#   'percentage': 1,
#   'datetime': '2025-10-30T08:00:00.000+01:00'},
#  {'value': 166.22,
#   'percentage': 1,
# ...

# %%
elect["included"][0]["attributes"]["values"]
# Out:
# {'value': 154.99,
#  'percentage': 0.5611919762473749,
#  'datetime': '2025-10-30T00:00:00.000+01:00'}

# %%
for dato in elect["included"][0]["attributes"]["values"]:
 print (dato["value"])
# Out:
# 154.99
# 146.04
# 138.81
# 133.61
# 123.62
# 121.38
# 139.94
# 159.68
# 183.9
# 166.22
# 184.88
# 157.46
# 133.46
# 131.72
# 65.35
# 78.29
# 119.72
# 168.04
# 246.73
# 247.65
# 264.33
# 242.97
# 168.34
# 155.06

# %%
precios = []

for dato in elect["included"][0]["attributes"]["values"]:
 pvp =dato["value"]
 precios.append(pvp)

# %%
from matplotlib import pyplot as plt
plt.plot(precios)

# %%
import json
import requests

# %%
centro = requests.get("https://datosabiertos.malaga.eu/recursos/deportes/equipamientos/da_deportesCentrosDeportivos-25830.geojson")

# %%
centro.text
# Out:
# '{"crs": {"type": "name", "properties": {"name": "urn:ogc:def:crs:EPSG::25830"}}, "totalFeatures": 16, "type": "FeatureCollection", "features": [{"geometry": {"type": "Point", "coordinates": [372850.087, 4068174.128, 0]}, "geometry_name": "SDOGEOMETRIA", "type": "Feature", "properties": {"TITULARIDAD": "MUNICIPAL", "URL": "http://www.valssport.com/", "PRECIOS": null, "DIRECCION": "AVENIDA DE JACINTO BENAVENTE, 16 ", "ACCESOPMR": "No", "INFOESP": [{"Espacio_deportivo": "Piscina cubierta", "Iluminacion": "Si", "Actividad_deportiva": "Actividades Acu\\u00e1ticas", "Dimensiones_en_metros": "25x16,67", "Tipo_de_pavimento": "Desconocido"}, {"Espacio_deportivo": "Piscina cubierta", "Iluminacion": "Si", "Actividad_deportiva": "Actividades Acu\\u00e1ticas", "Dimensiones_en_metros": "25x16,67", "Tipo_de_pavimento": "Desconocido"}, {"Espacio_deportivo": "Piscina cubierta", "Iluminacion": "Si", "Actividad_deportiva": "Actividades Acu\\u00e1ticas", "Dimensiones_en_metros": "16,67x6", "Tipo_de_pav
# ...

# %%
json.loads(centro.text)
# Out:
# {'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:EPSG::25830'}},
#  'totalFeatures': 16,
#  'type': 'FeatureCollection',
#  'features': [{'geometry': {'type': 'Point',
#     'coordinates': [372850.087, 4068174.128, 0]},
#    'geometry_name': 'SDOGEOMETRIA',
#    'type': 'Feature',
#    'properties': {'TITULARIDAD': 'MUNICIPAL',
#     'URL': 'http://www.valssport.com/',
#     'PRECIOS': None,
#     'DIRECCION': 'AVENIDA DE JACINTO BENAVENTE, 16 ',
#     'ACCESOPMR': 'No',
#     'INFOESP': [{'Espacio_deportivo': 'Piscina cubierta',
#       'Iluminacion': 'Si',
#       'Actividad_deportiva': 'Actividades Acuáticas',
#       'Dimensiones_en_metros': '25x16,67',
#       'Tipo_de_pavimento': 'Desconocido'},
#      {'Espacio_deportivo': 'Piscina cubierta',
#       'Iluminacion': 'Si',
#       'Actividad_deportiva': 'Actividades Acuáticas',
#       'Dimensiones_en_metros': '25x16,67',
#       'Tipo_de_pavimento': 'Desconocido'},
# ...

# %%
depor = json.loads(centro.text)

# %%
depor ["features"][1]["properties"]["INFOESP"]
# Out:
# [{'Espacio_deportivo': 'Piscina al aire libre',
#   'Iluminacion': 'Si',
#   'Tipo_de_pavimento': 'Desconocido',
#   'Dimensiones_en_metros': '9x6',
#   'Actividad_deportiva': 'Actividades Acuáticas'},
#  {'Espacio_deportivo': 'Piscina al aire libre',
#   'Iluminacion': 'Si',
#   'Tipo_de_pavimento': 'Desconocido',
#   'Dimensiones_en_metros': '9x6',
#   'Actividad_deportiva': 'Actividades Acuáticas'},
#  {'Espacio_deportivo': 'Piscina cubierta',
#   'Iluminacion': 'Si',
#   'Tipo_de_pavimento': 'Desconocido',
#   'Dimensiones_en_metros': '20X10',
#   'Actividad_deportiva': 'Actividades Acuáticas'},
#  {'Espacio_deportivo': 'Piscina cubierta',
#   'Iluminacion': 'Si',
#   'Tipo_de_pavimento': 'Desconocido',
#   'Dimensiones_en_metros': '20X10',
#   'Actividad_deportiva': 'Actividades Acuáticas'},
#  {'Espacio_deportivo': 'Piscina cubierta',
#   'Iluminacion': 'Si',
#   'Tipo_de_pavimento': 'Desconocido',
#   'Dimensiones_en_metros': '10X6',
# ...

# %%
depor ["features"][1]["properties"]["INFOESP"]
# Out:
# [{'Espacio_deportivo': 'Piscina al aire libre',
#   'Iluminacion': 'Si',
#   'Tipo_de_pavimento': 'Desconocido',
#   'Dimensiones_en_metros': '9x6',
#   'Actividad_deportiva': 'Actividades Acuáticas'},
#  {'Espacio_deportivo': 'Piscina al aire libre',
#   'Iluminacion': 'Si',
#   'Tipo_de_pavimento': 'Desconocido',
#   'Dimensiones_en_metros': '9x6',
#   'Actividad_deportiva': 'Actividades Acuáticas'},
#  {'Espacio_deportivo': 'Piscina cubierta',
#   'Iluminacion': 'Si',
#   'Tipo_de_pavimento': 'Desconocido',
#   'Dimensiones_en_metros': '20X10',
#   'Actividad_deportiva': 'Actividades Acuáticas'},
#  {'Espacio_deportivo': 'Piscina cubierta',
#   'Iluminacion': 'Si',
#   'Tipo_de_pavimento': 'Desconocido',
#   'Dimensiones_en_metros': '20X10',
#   'Actividad_deportiva': 'Actividades Acuáticas'},
#  {'Espacio_deportivo': 'Piscina cubierta',
#   'Iluminacion': 'Si',
#   'Tipo_de_pavimento': 'Desconocido',
#   'Dimensiones_en_metros': '10X6',
# ...

# %%
for dato in depor ["features"][1]["properties"]["INFOESP"]:
 print (dato["Espacio_deportivo"], dato ["Actividad_deportiva"])
# Out:
# Piscina al aire libre Actividades Acuáticas
# Piscina al aire libre Actividades Acuáticas
# Piscina cubierta Actividades Acuáticas
# Piscina cubierta Actividades Acuáticas
# Piscina cubierta Actividades Acuáticas
# Piscina cubierta Actividades Acuáticas
# Sala usos múltiples Actividades Dirigidas
# Sala usos múltiples Actividades Dirigidas
# Sala especializada Artes Marciales
# Sala especializada Artes Marciales
# Sala especializada Ciclo Indoor
# Sala especializada Ciclo Indoor
# Sala especializada Fitness/Cardio/Musculación
# Sala especializada Fitness/Cardio/Musculación
# Sala especializada Fitness/Cardio/Musculación
# Sala especializada Fitness/Cardio/Musculación
# Piscina cubierta Hidroterapia-SPA
# Piscina cubierta Hidroterapia-SPA
# Pista de pádel al aire libre Pádel
# Pista de pádel al aire libre Pádel
# Pista de pádel al aire libre Pádel
# Pista de pádel al aire libre Pádel
# Pista de pádel al aire libre Pádel
# Pista de pádel al aire libre Pádel
# ...

# %%
agua = requests.get("https://datosabiertos.malaga.eu/recursos/ambiente/fuentesaguapotable/da_medioAmbiente_fuentes-25830.geojson")

# %%
agua.text
# Out:
# '{"type":"FeatureCollection","totalFeatures":344,"features":[{"type":"Feature","id":"da_medioAmbiente_fuentes.fid-3213f16f_1999e386e26_3a3c","geometry":{"type":"Point","coordinates":[373951.2741,4064845.7951]},"geometry_name":"wkb_geometry","properties":{"ogc_fid":18873,"nombre":"La malagueta- Redding"}},{"type":"Feature","id":"da_medioAmbiente_fuentes.fid-3213f16f_1999e386e26_3a3d","geometry":{"type":"Point","coordinates":[373594.488,4064637.2732]},"geometry_name":"wkb_geometry","properties":{"ogc_fid":18874,"nombre":"Paseo de los curas teatro Eduardo Ocon I"}},{"type":"Feature","id":"da_medioAmbiente_fuentes.fid-3213f16f_1999e386e26_3a3e","geometry":{"type":"Point","coordinates":[373599.2149,4064636.7595]},"geometry_name":"wkb_geometry","properties":{"ogc_fid":18875,"nombre":"Paseo de los curas teatro Eduardo Ocon I"}},{"type":"Feature","id":"da_medioAmbiente_fuentes.fid-3213f16f_1999e386e26_3a3f","geometry":{"type":"Point","coordinates":[373359.9053,4064558.63]},"geometry_name":"w
# ...

# %%
json.loads(agua.text)
# Out:
# {'type': 'FeatureCollection',
#  'totalFeatures': 344,
#  'features': [{'type': 'Feature',
#    'id': 'da_medioAmbiente_fuentes.fid-3213f16f_1999e386e26_3a3c',
#    'geometry': {'type': 'Point', 'coordinates': [373951.2741, 4064845.7951]},
#    'geometry_name': 'wkb_geometry',
#    'properties': {'ogc_fid': 18873, 'nombre': 'La malagueta- Redding'}},
#   {'type': 'Feature',
#    'id': 'da_medioAmbiente_fuentes.fid-3213f16f_1999e386e26_3a3d',
#    'geometry': {'type': 'Point', 'coordinates': [373594.488, 4064637.2732]},
#    'geometry_name': 'wkb_geometry',
#    'properties': {'ogc_fid': 18874,
#     'nombre': 'Paseo de los curas teatro Eduardo Ocon I'}},
#   {'type': 'Feature',
#    'id': 'da_medioAmbiente_fuentes.fid-3213f16f_1999e386e26_3a3e',
#    'geometry': {'type': 'Point', 'coordinates': [373599.2149, 4064636.7595]},
#    'geometry_name': 'wkb_geometry',
#    'properties': {'ogc_fid': 18875,
#     'nombre': 'Paseo de los curas teatro Eduardo Ocon I'}},
#   {'type': 'Feature',
# ...

# %%
agua["geometry"]["geometry"]

# %% [markdown]
# #Exploracion de CSVs

# %%
import pandas as pd

# %% [markdown]
# ##Dataset Bicis

# %%
bicis = pd.read_csv("/content/drive/MyDrive/day.csv")

# %%
bicis
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
bicis["cnt"].hist()
# Out:
# <Axes: >

# %%
bicis["cnt"].hist(bins=30)
# Out:
# <Axes: >

# %%
bicis["mnth"].hist()
# Out:
# <Axes: >

# %%
bicis["mnth"].hist(bins=12)
# Out:
# <Axes: >

# %%
data = []
for i in range (1,13):
  data.append(bicis[bicis["mnth"]==i]["temp"])

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e7f5d3523f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e7f5d0b0050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e7f5d350320>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7e7f5d2f0b90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7e7f5d1d6180>,
# ...
#  'means': []}

# %%
data = []
for i in range (1,13):
  data.append(bicis[bicis["mnth"]==i]["cnt"])

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e7f5c3e2150>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e7f5c3e26f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e7f5c3e1f10>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7e7f5c3e2d20>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7e7f5c3e3050>,
# ...
#  'means': []}

# %%
bicis.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
import pandas as pd

# %% [markdown]
# ##Dataset Bank

# %%
bank = pd.read_csv("/content/drive/MyDrive/BANK.csv" , sep=";")

# %%
bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
bank.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
bank[['age', 'balance', 'day', 'duration', 'campaign', 'pdays','previous']].corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %%
plt.matshow(bank[['age', 'balance', 'day', 'duration', 'campaign', 'pdays','previous']].corr())
