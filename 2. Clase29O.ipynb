# %%
completado = True
estado = ""
if completado == True :
  estado = "Completado"
else:
  estado = "No Acabado"

# %%
estado = "Completado" if completado == completado == True else "No Acabado"

# %%
#  | (OR) una de las condiciones se deben cumplir
# & (AND) todas las condiciones se deben cumplir
# o (XOR) exclusive OR o una cosa o la otra pero no las 2 al tiempo

# %%
for animal in ["perro","gato","loro",1]:
 print (animal)
# Out:
# perro
# gato
# loro
# 1

# %%
lista = ["perro","gato","loro",1]
len(lista)
# Out:
# 4

# %%
for i in range (len(lista)):
  print(lista[i])
# Out:
# perro
# gato
# loro
# 1

# %%
len(lista)
# Out:
# 4

# %%
for numero in range (0,10):
    if numero % 2 == 0 :
        print (numero)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
texto = "No por mucho madrugar amanece mas temprano"

# %%
for letra in texto:
  print (texto)
# Out:
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# No por mucho madrugar amanece mas temprano
# ...

# %%
indice = 0
while indice < 7 :
  print (texto[indice])
  indice = indice +1
# Out:
# N
# o
#
# p
# o
# r

# %%
##ESTRUCTURAS DE DATOS##
# LISTAS [1,2,3,4]
# DICCIONARIOS [X:3 ,Y:8 ,Z: 9, NOMBRE: "Juan "]


# LISTA [2] = posicion   #  diccionario ["NOMBRE"]

# %%
lista = ["perro", "gato", "loro"]

# %%
lista = []
lista.append("perro")
lista.append("gato")
lista.append("loro")

# %%
lista.count("loro")
# Out:
# 1

# %%
len(lista)
# Out:
# 3

# %%
lista.remove("gato")

# %%
print(lista)
# Out:
# ['perro', 'loro']

# %%
lista.append("gato")

# %%
print(lista)
# Out:
# ['perro', 'loro', 'gato']

# %%
diccionario = {"X":3 , "Y": 4 , "Z":9}

# %%
diccionario["Y"]
# Out:
# 4

# %%
cliente = {"Nombre": "Juan", "Apellido": "Gomez", "Edad": 38}

# %%
cliente = {}
cliente['Nombre'] = "Juan"
cliente["Apellido"] = "Gomez"
cliente["Edad"]= 38

# %%
cliente["Edad"]
# Out:
# 38

# %%
cliente = {"Nombre": "Juan", "Apellido": "Gomez", "Edad": 38}
cliente ["Barrrio"] = "Refugio"

# %%
print(cliente)
# Out:
# {'Nombre': 'Juan', 'Apellido': 'Gomez', 'Edad': 38, 'Barrrio': 'Refugio'}

# %%
cliente["Barrrio"]
# Out:
# 'Refugio'

# %%
#Lista diferente del # Array redes neuronales NUMPY libreria matematica
#lista es facil por que se modifica (cuenta en orden las posiciones)
#array siempre guarda el espacio entonces es mas costoso (busca la posicion en segun los huecos)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
bank = pd.read_csv("/content/drive/MyDrive/ESESA Lessons/DataSets/BANK.csv", sep=";", decimal=",")

# %%
bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
print(bank["age"].median())
# Out:
# 39.0

# %%
bank["marital"]
# Out:
# 0         married
# 1          single
# 2         married
# 3         married
# 4          single
#            ...
# 45206     married
# 45207    divorced
# 45208     married
# 45209     married
# 45210     married
# Name: marital, Length: 45211, dtype: object

# %%
bank["marital"].value_counts()
# Out:
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64

# %%
bank["marital"].str.capitalize()
# Out:
# 0         Married
# 1          Single
# 2         Married
# 3         Married
# 4          Single
#            ...
# 45206     Married
# 45207    Divorced
# 45208     Married
# 45209     Married
# 45210     Married
# Name: marital, Length: 45211, dtype: object

# %%
bank["marital"].str.upper()
# Out:
# 0         MARRIED
# 1          SINGLE
# 2         MARRIED
# 3         MARRIED
# 4          SINGLE
#            ...
# 45206     MARRIED
# 45207    DIVORCED
# 45208     MARRIED
# 45209     MARRIED
# 45210     MARRIED
# Name: marital, Length: 45211, dtype: object

# %%
bank["marital"].str.replace("ma","xx")
# Out:
# 0         xxrried
# 1          single
# 2         xxrried
# 3         xxrried
# 4          single
#            ...
# 45206     xxrried
# 45207    divorced
# 45208     xxrried
# 45209     xxrried
# 45210     xxrried
# Name: marital, Length: 45211, dtype: object

# %%
#Para Cargar al DataSet

# %%
bank ["marital"] = bank["marital"].str.replace("ma","xx")

# %%
bank ["marital"]
# Out:
# 0         xxrried
# 1          single
# 2         xxrried
# 3         xxrried
# 4          single
#            ...
# 45206     xxrried
# 45207    divorced
# 45208     xxrried
# 45209     xxrried
# 45210     xxrried
# Name: marital, Length: 45211, dtype: object

# %%
bank ["marital"] = bank["marital"].str.replace("xx","ma")

# %%
bank ["marital"]
# Out:
# 0         married
# 1          single
# 2         married
# 3         married
# 4          single
#            ...
# 45206     married
# 45207    divorced
# 45208     married
# 45209     married
# 45210     married
# Name: marital, Length: 45211, dtype: object

# %%
#   inplace=True  ejecuta directo sin definir nuevamente el dataset
#  axis=1    ejecuta todo en el axis y------

# %%
bank = bank.drop(columns=["marital"])
# o
bank.drop((columns=["marital"]), inplace=True)
# o
del bank["marital"]
# Out:
#   File "/tmp/ipython-input-2722397071.py", line 3
#     bank.drop((columns=["marital"]), inplace=True)
#                ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
bank[["age","day"]]
# Out:
#        age  day
# 0       58    5
# 1       44    5
# 2       33    5
# 3       47    5
# 4       33    5
# ...    ...  ...
# 45206   51   17
# 45207   71   17
# 45208   72   17
# 45209   57   17
# 45210   37   17
#
# [45211 rows x 2 columns]

# %%
bank[["age","day"]].sum()
# Out:
# age    1850767
# day     714624
# dtype: int64

# %%
bank[["age","day"]].sum(axis=1)
# Out:
# 0        63
# 1        49
# 2        38
# 3        52
# 4        38
#          ..
# 45206    68
# 45207    88
# 45208    89
# 45209    74
# 45210    54
# Length: 45211, dtype: int64

# %%
bank.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
bank["age"].idxmin()

# posicion en la fila
# Out:
# 40736

# %%
bank["age"].idxmax()
# Out:
# 33699

# %%
bank[bank["age"]==bank["age"].max()]
# Out:
#        age      job   marital  education default  balance housing loan  \
# 33699   95  retired  divorced    primary      no     2282      no   no
# 41663   95  retired   married  secondary      no        0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 33699  telephone   21   apr       207        17     -1         0  unknown  yes
# 41663  telephone    1   oct       215         1     -1         0  unknown   no

# %%
bank.age

 #trae sin corchetes pero no debe tener espacios
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64

# %%
bank[10:20][["age","marital"]]
# Out:
#     age   marital
# 10   41  divorced
# 11   29    single
# 12   53   married
# 13   58   married
# 14   57   married
# 15   51   married
# 16   45    single
# 17   57   married
# 18   60   married
# 19   33   married

# %%
bank[10:20][["age","marital"]].max()
# Out:
# age            60
# marital    single
# dtype: object

# %%
bank[bank["marital"].str.startswith("s")]
# Out:
#        age          job marital  education default  balance housing loan  \
# 1       44   technician  single  secondary      no       29     yes   no
# 4       33      unknown  single    unknown      no        1      no   no
# 6       28   management  single   tertiary      no      447     yes  yes
# 9       43   technician  single  secondary      no      593     yes   no
# 11      29       admin.  single  secondary      no      390     yes   no
# ...    ...          ...     ...        ...     ...      ...     ...  ...
# 45197   36   management  single  secondary      no     1511     yes   no
# 45199   34  blue-collar  single  secondary      no     1475     yes   no
# 45202   34       admin.  single  secondary      no      557      no   no
# 45203   23      student  single   tertiary      no      113      no   no
# 45205   25   technician  single  secondary      no      505      no  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
bank["age"].values
# Out:
# array([58, 44, 33, ..., 72, 57, 37])

# %%
bank["age"].at[1] = 0

# %%
bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1        0    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
bank["age"].hasnans
# Out:
# False

# %%
bank["age"].plot()
 #serie continuada
# Out:
# <Axes: >

# %%
bank["age"].hist()
 #histograma
# Out:
# <Axes: >

# %%
bank["age"].hist(bins = 8)
# BINS division en el histograma
# Out:
# <Axes: >

# %%
#  .PLOT.PIE()  grafico de tarta pero no es recomendable asi

# %%
bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1        0    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
bank["age"].at[1]
# Out:
# np.int64(0)

# %%
bank["marital"].value_counts()
# Out:
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64

# %%
bank["age"].sort_values().plot()
# Out:
# <Axes: >

# %%
bank["age"].sort_values()
# Out:
# 1         0
# 42146    18
# 41252    18
# 41222    18
# 40744    18
#          ..
# 44262    93
# 44420    93
# 31233    94
# 41663    95
# 33699    95
# Name: age, Length: 45211, dtype: int64

# %%
bank["age"].at[1] = 44

# %%
bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
bank["age"].sort_values().plot()
# Out:
# <Axes: >

# %%
bank['age'].dropna()
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64

# %%
# agregaciones principales -SUM-MEAN-COUNT-MAX-MIN

# %%
bank['age'].agg(["mean","max","min"])
# Out:
# mean    40.93621
# max     95.00000
# min     18.00000
# Name: age, dtype: float64

# %%
bank[["marital","age","balance"]].groupby("marital").agg(["mean","max","min", "count"])
# Out:
#                 age                     balance
#                mean max min  count         mean     max   min  count
# marital
# divorced  45.782984  95  24   5207  1178.872287   66721 -4057   5207
# married   43.408099  95  20  27214  1425.925590   98417 -6847  27214
# single    33.703440  86  18  12790  1301.497654  102127 -8019  12790

# %%
bank[["default","age","balance"]].groupby("default").agg(["mean","max","min", "count"])
# Out:
#                age                     balance
#               mean max min  count         mean     max   min  count
# default
# no       40.961934  95  18  44396  1389.806424  102127 -4057  44396
# yes      39.534969  71  21    815  -137.624540   16486 -8019    815

# %% [markdown]
# ##Analisis Exploratorios
# Variables
#
# 1.   Cualitativas ORDINALES NOMINALES
# 2.   Cuantitativas DISCRETAS CONTABLES
#
#
#
#   Histograma = Distribucion de frecuencia (relativa y acumulado)

# %%
bank[bank["balance"]<20000] ["balance"].hist(bins=100)
# Out:
# <Axes: >

# %%
bank[(bank["balance"]<20000) & (bank["balance"] > -1000)] ["balance"].hist(bins=100)
# Out:
# <Axes: >

# %%
bank['duration'].agg("mean")
# Out:
# np.float64(258.1630797814691)

# %%
bank['duration'].mean()
# Out:
# np.float64(258.1630797814691)

# %%
bank['duration'].median()
# Out:
# 180.0

# %%
bank['duration'].idxmax()
# Out:
# 24148

# %%
bank['duration'].max()
# Out:
# 4918

# %% [markdown]
# #Curva de Gauss
#
# 25%	Primer Cuartil
# 50%	Mediana
# 75% Tercer Cuartil
#
# Entre cuartiles: rango intercuartilico (se ussa para ver donde esta la gran cantidad de datos, identificar la grafica sin usar la grafica)
#
#
# MEDIDA DE DISPERSION identificar los extremos cuanto se aleja de la media
# DESV TIPICA  curva de gausch estadistica

# %%
bank['duration'].describe()
# Out:
# count    45211.000000
# mean       258.163080
# std        257.527812
# min          0.000000
# 25%        103.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: duration, dtype: float64

# %%
bank[(bank["duration"]<1500)] ["duration"].hist()
# Out:
# <Axes: >

# %%
bank[["age"]].boxplot()
# Out:
# <Axes: >

# %%
bank['age'].describe()
# Out:
# count    45211.000000
# mean        40.936210
# std         10.618762
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64
